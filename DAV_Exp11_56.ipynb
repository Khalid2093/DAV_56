# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalid2093/DAV_56/blob/main/DAV_Exp11_56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment :- 11**

# %% [markdown]
# ## **Aim:-**
# Explore Data Visualization libraries in Python and R
#
# ## **Task to be performed :-**
# 1.Explore Top-5 Data Visualization Libraries in Python (w.r.t Features & Applications)
#
# 2.Explore Top-5 Data Visualization Libraries in R (w.r.t Features & Applications)
#
# 3.Install 2 Libraries each for Python and R
#
# 4.Perform simple experiments on the 2 identified libraries each for Python and R

# %% [markdown]
# # **Python** :-
#
# Matplotlib Library

# %%
!pip install matplotlib

# %%
import matplotlib.pyplot as plt

age=[25,50,75]
income=[25,100,30]
plt.plot(age,income)
plt.title("Age vs Income Salary", fontsize=15, color="red")
plt.ylabel("Income per month (In Thousands)")
plt.xlabel("Ages")
plt.show()

# %% [markdown]
# # **Python** :-
#
# Seaborn Library

# %%
!pip install seaborn

# %%
!pip install pandas

# %%
import seaborn as sns
import pandas as pd

data = pd.DataFrame([[25, 25, 75], [50, 100, 150], [75, 25, 25]], columns=['Ages', 'Income per month (In thousands)', 'test'])

sns.lineplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# # **R:-**
#
# ggplot2 Library

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
# Sample data
x <- c(1, 2, 3, 4, 5)
y <- c(2, 4, 5, 4, 3)

# Basic scatter plot
ggplot(data.frame(x, y), aes(x = x, y = y)) + geom_point()
# Out:
# plot without title

# %%
# Sample data
x <- c(1, 2, 3, 4, 5)
y <- c(1, 3, 5, 4, 2)

# Line plot
ggplot(data.frame(x, y), aes(x = x, y = y)) + geom_line()
# Out:
# plot without title

# %% [markdown]
# # **R :-**
#
# Plotly Library

# %%
install.packages("lattice")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(lattice)

# %%
# Sample data
x <- c(1, 2, 3, 4, 5)
y <- c(2, 4, 5, 4, 3)

# Scatter plot
xyplot(y ~ x)
# Out:
# plot without title

# %%
# Sample data
categories <- c("A", "B", "C")
values <- c(10, 20, 15)

# Bar chart
barplot(values ~ categories)
# Out:
# plot without title

# %% [markdown]
# # **Conclusion :-**
#
# Explored Matplotlib, Seaborn (Python) and ggplot2, Lattice (R) for data visualization. Each offers unique strengths: Matplotlib (power), Seaborn (ease), ggplot2 (clarity), Lattice (comparisons). Personal preference and project needs will guide library choice.
